# %%
import sys, os, platform
print("sys.executable:", sys.executable)
print("Python:", platform.python_version())
print("site-packages:", [p for p in sys.path if p.endswith("site-packages")][:2])
# Out:
# sys.executable: /Users/krshnajaya/Desktop/bio214-project1/bio214-proj1-venv/bin/python
# Python: 3.11.13
# site-packages: ['/Users/krshnajaya/Desktop/bio214-project1/bio214-proj1-venv/lib/python3.11/site-packages']

# %%
import pandas as pd
import numpy as np
import matplotlib as mt
